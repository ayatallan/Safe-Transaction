# %% [markdown]
# The goal of this project build a fraud detection model using an unlabeled dataset from Palpay, using popular machine learning-based techniques for anomaly detection.

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn
import matplotlib.dates as md
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 1.Data Preprocessing

# %% [markdown]
# #### 1.1 Loading Data

# %%
data = pd.read_csv("palpay_card_transactions_sample.csv")

# %%
data
# Out:
#       Transaction Date  Card Category            Card Type  \
# 0              1-Jan-23   Palpay Cards  Visa Classic Debit
# 1              1-Jan-23   Palpay Cards  Visa Classic Debit
# 2              1-Jan-23   Palpay Cards  Visa Classic Debit
# 3              1-Jan-23   Palpay Cards  Visa Classic Debit
# 4              1-Jan-23   Palpay Cards  Visa Classic Debit
# ...                 ...            ...                 ...
# 88089         30-Jun-23   Palpay Cards  Visa Classic Debit
# 88090         30-Jun-23   Palpay Cards  Visa Classic Debit
# 88091         30-Jun-23   Palpay Cards  Visa Classic Debit
# 88092         30-Jun-23   Palpay Cards  Visa Classic Debit
# 88093         30-Jun-23   Palpay Cards  Visa Classic Debit
#
#                   Card Type AR  Channel       Channel AR  Transaction Type  \
# 0      ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# 1      ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# 2      ???? ?????? ??? ????????      POS       ???? ?????         Purchase
# 3      ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# 4      ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# ...                         ...      ...              ...              ...
# 88089  ???? ?????? ??? ????????      POS       ???? ?????         Purchase
# 88090  ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# 88091  ???? ?????? ??? ????????      ATM  ???????? ??????       Withdrawal
# 88092  ???? ?????? ??? ????????      POS       ???? ?????         Purchase
# 88093  ???? ?????? ??? ????????      POS       ???? ?????         Purchase
#
#       Transaction Type Group  Entry Mode Transaction Status   Outlet ID  \
# 0           ATM Transactions  Chip & Pin           PROCESSED  110002011
# 1           ATM Transactions  Chip & Pin           PROCESSED  110002011
# 2                  Purchases  Chip & Pin           PROCESSED  110002413
# 3           ATM Transactions  Chip & Pin           PROCESSED  110002011
# 4           ATM Transactions       Other           PROCESSED  800000010
# ...                      ...         ...                 ...        ...
# 88089              Purchases     Paywave           PROCESSED  310103241
# 88090       ATM Transactions       Other           PROCESSED   10000401
# 88091       ATM Transactions       Other           PROCESSED   10000401
# 88092              Purchases     Paywave           PROCESSED  400000936
# 88093              Purchases     Paywave           PROCESSED  260000127
#
#        Merchant Acronym                             Merchant Desc  \
# 0           ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 1           ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 2         YOUSEF MARKET  YOUSEF MARKET           >YOUSEF MARKETPS
# 3           ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 4        DEIR BALAH OLD  BOP Salah ElDain St      GAZA STRIP   PS
# ...                 ...                                       ...
# 88089   AL BADER MARKET  AL BADER MARKET         >BETHLEHEM    PS
# 88090    OMAR ELMOKHTAR  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS
# 88091    OMAR ELMOKHTAR  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS
# 88092        FAHED REST  FAHED REST              >ALREMAL      PS
# 88093   KAHLON SHAWARMA  KAHLON SHAWARMA         >RAFIDIA      PS
#
#       Merchant Country           Merchant Activity   \
# 0            Palestine                        Other
# 1            Palestine                        Other
# 2            Palestine                          NaN
# 3            Palestine                        Other
# 4            Palestine                        Other
# ...                ...                          ...
# 88089        Palestine                          NaN
# 88090        Palestine                        Other
# 88091        Palestine                        Other
# 88092        Palestine  Entertainment & Restaurants
# 88093        Palestine                          NaN
#
#             Merchant Activity sub  Client Code  Amount   Amount USD  \
# 0                   AUTOMATED CASH   P00589393   -300.0     -86.460
# 1                   AUTOMATED CASH   P00589393   -100.0     -28.820
# 2      Grocery stores,supermarkets   P00589801    -50.0     -14.409
# 3                   AUTOMATED CASH   P00565050  -1100.0    -317.000
# 4                   AUTOMATED CASH   P00575741   -150.0     -43.230
# ...                            ...         ...      ...         ...
# 88089  Grocery stores,supermarkets   P00357371    -19.0      -5.205
# 88090               AUTOMATED CASH   P00494710   -600.0    -600.000
# 88091               AUTOMATED CASH   P00352736  -1000.0   -1000.000
# 88092    Eating places,Restaurants   P00635693     -9.0      -2.466
# 88093    Eating places,Restaurants   P00518129    -96.0     -26.301
#
#       Transaction Currency
# 0                       ILS
# 1                       ILS
# 2                       ILS
# 3                       ILS
# 4                       ILS
# ...                     ...
# 88089                   ILS
# 88090                   USD
# 88091                   USD
# 88092                   ILS
# 88093                   ILS
#
# [88094 rows x 20 columns]

# %% [markdown]
# #### 1.2 Understand data

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88094 entries, 0 to 88093
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Transaction Date        88094 non-null  object
#  1   Card Category           88094 non-null  object
#  2   Card Type               88094 non-null  object
#  3   Card Type AR            88094 non-null  object
#  4   Channel                 88094 non-null  object
#  5   Channel AR              88094 non-null  object
#  6   Transaction Type        88094 non-null  object
#  7   Transaction Type Group  88094 non-null  object
#  8   Entry Mode              88094 non-null  object
#  9   Transaction Status      88094 non-null  object
#  10  Outlet ID               88094 non-null  int64
#  11   Merchant Acronym       87524 non-null  object
#  12  Merchant Desc           87514 non-null  object
#  13  Merchant Country        88094 non-null  object
#  14  Merchant Activity       49577 non-null  object
#  15  Merchant Activity sub   88094 non-null  object
#  16  Client Code             88094 non-null  object
#  17  Amount                  88094 non-null  float64
#  18  Amount USD              88094 non-null  float64
#  19  Transaction Currency    88094 non-null  object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 13.4+ MB
# None

# %%
print(data.columns)
# Out:
# Index(['Transaction Date ', 'Card Category ', 'Card Type', 'Card Type AR ',
#        'Channel ', 'Channel AR ', 'Transaction Type', 'Transaction Type Group',
#        'Entry Mode', 'Transaction Status ', 'Outlet ID', ' Merchant Acronym',
#        'Merchant Desc', 'Merchant Country', 'Merchant Activity ',
#        'Merchant Activity sub ', 'Client Code', 'Amount ', 'Amount USD',
#        'Transaction Currency '],
#       dtype='object')

# %%
data.shape
# Out:
# (88094, 20)

# %%
print(data['Transaction Date '].head(10))
# Out:
# 0    1-Jan-23
# 1    1-Jan-23
# 2    1-Jan-23
# 3    1-Jan-23
# 4    1-Jan-23
# 5    1-Jan-23
# 6    1-Jan-23
# 7    1-Jan-23
# 8    1-Jan-23
# 9    1-Jan-23
# Name: Transaction Date , dtype: object

# %%
data['Transaction Date '] = pd.to_datetime(data['Transaction Date '])

# %% [markdown]
# #### 1.3 Delete duplicate columns

# %%
data.drop(columns=['Card Type AR ', 'Channel AR ', 'Amount ','Transaction Currency '], inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Transaction Date ', 'Card Category ', 'Card Type', 'Channel ',
#        'Transaction Type', 'Transaction Type Group', 'Entry Mode',
#        'Transaction Status ', 'Outlet ID', ' Merchant Acronym',
#        'Merchant Desc', 'Merchant Country', 'Merchant Activity ',
#        'Merchant Activity sub ', 'Client Code', 'Amount USD'],
#       dtype='object')

# %%
data
# Out:
#       Transaction Date  Card Category            Card Type Channel   \
# 0            2023-01-01   Palpay Cards  Visa Classic Debit      ATM
# 1            2023-01-01   Palpay Cards  Visa Classic Debit      ATM
# 2            2023-01-01   Palpay Cards  Visa Classic Debit      POS
# 3            2023-01-01   Palpay Cards  Visa Classic Debit      ATM
# 4            2023-01-01   Palpay Cards  Visa Classic Debit      ATM
# ...                 ...            ...                 ...      ...
# 88089        2023-06-30   Palpay Cards  Visa Classic Debit      POS
# 88090        2023-06-30   Palpay Cards  Visa Classic Debit      ATM
# 88091        2023-06-30   Palpay Cards  Visa Classic Debit      ATM
# 88092        2023-06-30   Palpay Cards  Visa Classic Debit      POS
# 88093        2023-06-30   Palpay Cards  Visa Classic Debit      POS
#
#       Transaction Type Transaction Type Group  Entry Mode Transaction Status   \
# 0           Withdrawal       ATM Transactions  Chip & Pin           PROCESSED
# 1           Withdrawal       ATM Transactions  Chip & Pin           PROCESSED
# 2             Purchase              Purchases  Chip & Pin           PROCESSED
# 3           Withdrawal       ATM Transactions  Chip & Pin           PROCESSED
# 4           Withdrawal       ATM Transactions       Other           PROCESSED
# ...                ...                    ...         ...                 ...
# 88089         Purchase              Purchases     Paywave           PROCESSED
# 88090       Withdrawal       ATM Transactions       Other           PROCESSED
# 88091       Withdrawal       ATM Transactions       Other           PROCESSED
# 88092         Purchase              Purchases     Paywave           PROCESSED
# 88093         Purchase              Purchases     Paywave           PROCESSED
#
#        Outlet ID  Merchant Acronym                             Merchant Desc  \
# 0      110002011       ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 1      110002011       ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 2      110002413     YOUSEF MARKET  YOUSEF MARKET           >YOUSEF MARKETPS
# 3      110002011       ALNASER NEW  BOP EL Naser St          GAZA STRIP   PS
# 4      800000010    DEIR BALAH OLD  BOP Salah ElDain St      GAZA STRIP   PS
# ...          ...               ...                                       ...
# 88089  310103241   AL BADER MARKET  AL BADER MARKET         >BETHLEHEM    PS
# 88090   10000401    OMAR ELMOKHTAR  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS
# 88091   10000401    OMAR ELMOKHTAR  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS
# 88092  400000936        FAHED REST  FAHED REST              >ALREMAL      PS
# 88093  260000127   KAHLON SHAWARMA  KAHLON SHAWARMA         >RAFIDIA      PS
#
#       Merchant Country           Merchant Activity   \
# 0            Palestine                        Other
# 1            Palestine                        Other
# 2            Palestine                          NaN
# 3            Palestine                        Other
# 4            Palestine                        Other
# ...                ...                          ...
# 88089        Palestine                          NaN
# 88090        Palestine                        Other
# 88091        Palestine                        Other
# 88092        Palestine  Entertainment & Restaurants
# 88093        Palestine                          NaN
#
#             Merchant Activity sub  Client Code  Amount USD
# 0                   AUTOMATED CASH   P00589393     -86.460
# 1                   AUTOMATED CASH   P00589393     -28.820
# 2      Grocery stores,supermarkets   P00589801     -14.409
# 3                   AUTOMATED CASH   P00565050    -317.000
# 4                   AUTOMATED CASH   P00575741     -43.230
# ...                            ...         ...         ...
# 88089  Grocery stores,supermarkets   P00357371      -5.205
# 88090               AUTOMATED CASH   P00494710    -600.000
# 88091               AUTOMATED CASH   P00352736   -1000.000
# 88092    Eating places,Restaurants   P00635693      -2.466
# 88093    Eating places,Restaurants   P00518129     -26.301
#
# [88094 rows x 16 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88094 entries, 0 to 88093
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Transaction Date        88094 non-null  datetime64[ns]
#  1   Card Category           88094 non-null  object
#  2   Card Type               88094 non-null  object
#  3   Channel                 88094 non-null  object
#  4   Transaction Type        88094 non-null  object
#  5   Transaction Type Group  88094 non-null  object
#  6   Entry Mode              88094 non-null  object
#  7   Transaction Status      88094 non-null  object
#  8   Outlet ID               88094 non-null  int64
#  9    Merchant Acronym       87524 non-null  object
#  10  Merchant Desc           87514 non-null  object
#  11  Merchant Country        88094 non-null  object
#  12  Merchant Activity       49577 non-null  object
#  13  Merchant Activity sub   88094 non-null  object
#  14  Client Code             88094 non-null  object
#  15  Amount USD              88094 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 10.8+ MB
# None

# %%
data.shape
# Out:
# (88094, 16)

# %% [markdown]
# #### 1.4 Handling duplicate rows

# %%
duplicate_rows = data.duplicated().sum()

# %%
duplicate_rows
# Out:
# 5460

# %%
duplicate_mask = data.duplicated(keep=False)

# %%
duplicate_rows1 = data[duplicate_mask]

# %%
duplicate_rows1
# Out:
#       Transaction Date  Card Category            Card Type    Channel   \
# 8            2023-01-01   Palpay Cards  Visa Classic Debit  E-Commerce
# 50           2023-01-01   Palpay Cards  Visa Classic Debit  E-Commerce
# 62           2023-01-01   Palpay Cards  Visa Classic Debit         ATM
# 93           2023-01-01   Palpay Cards  Visa Classic Debit         POS
# 124          2023-01-01   Palpay Cards  Visa Classic Debit         POS
# ...                 ...            ...                 ...         ...
# 88016        2023-06-29   Palpay Cards  Visa Classic Debit         ATM
# 88017        2023-06-29   Palpay Cards  Visa Classic Debit         ATM
# 88020        2023-06-29   Palpay Cards  Visa Classic Debit         ATM
# 88025        2023-06-29   Palpay Cards  Visa Classic Debit         ATM
# 88026        2023-06-29   Palpay Cards  Visa Classic Debit         ATM
#
#       Transaction Type Transaction Type Group  Entry Mode Transaction Status   \
# 8             Purchase              Purchases  E-commerce           PROCESSED
# 50            Purchase              Purchases  E-commerce           PROCESSED
# 62          Withdrawal       ATM Transactions       Other           PROCESSED
# 93            Purchase              Purchases     Paywave           PROCESSED
# 124           Purchase              Purchases     Paywave           PROCESSED
# ...                ...                    ...         ...                 ...
# 88016       Withdrawal       ATM Transactions       Other           PROCESSED
# 88017       Withdrawal       ATM Transactions       Other           PROCESSED
# 88020       Withdrawal       ATM Transactions       Other           PROCESSED
# 88025       Withdrawal       ATM Transactions       Other           PROCESSED
# 88026       Withdrawal       ATM Transactions  Chip & Pin           PROCESSED
#
#         Outlet ID          Merchant Acronym  \
# 8      9999999999            APPLE.COM/BILL
# 50     9999999999            APPLE.COM/BILL
# 62       10000401            OMAR ELMOKHTAR
# 93      301001036  EYAD HALAWAH SUPERMARKET
# 124     301001036  EYAD HALAWAH SUPERMARKET
# ...           ...                       ...
# 88016    10000401            OMAR ELMOKHTAR
# 88017    10000401            OMAR ELMOKHTAR
# 88020    10000401            OMAR ELMOKHTAR
# 88025    10000401            OMAR ELMOKHTAR
# 88026   400800010                   REMAL 4
#
#                                   Merchant Desc Merchant Country  \
# 8           APPLE.COM/BILL           ITUNES.COM          VISA_IE
# 50          APPLE.COM/BILL           ITUNES.COM          VISA_IE
# 62     BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS        Palestine
# 93     EYAD HALAWAH SUPERMARKET>EYAD HALAWAH PS        Palestine
# 124    EYAD HALAWAH SUPERMARKET>EYAD HALAWAH PS        Palestine
# ...                                         ...              ...
# 88016  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS        Palestine
# 88017  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS        Palestine
# 88020  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS        Palestine
# 88025  BOP OMAR ELMOKHTAR ST -  GAZA STRIP   PS        Palestine
# 88026  BOP Remal BOP BRH        GAZA STRIP   PS        Palestine
#
#                  Merchant Activity             Merchant Activity sub   \
# 8                               NaN  Digital Books Media: Books, movi
# 50                              NaN  Digital Books Media: Books, movi
# 62                            Other                    AUTOMATED CASH
# 93     Supermarkets & Confectionary       Grocery stores,supermarkets
# 124    Supermarkets & Confectionary       Grocery stores,supermarkets
# ...                             ...                               ...
# 88016                         Other                    AUTOMATED CASH
# 88017                         Other                    AUTOMATED CASH
# 88020                         Other                    AUTOMATED CASH
# 88025                         Other                    AUTOMATED CASH
# 88026                           NaN                    AUTOMATED CASH
#
#       Client Code  Amount USD
# 8       P00285871      -1.020
# 50      P00285871      -1.020
# 62      P00589862     -86.460
# 93      P00557265      -2.882
# 124     P00557265      -2.882
# ...           ...         ...
# 88016   P00569588     -41.100
# 88017   P00569588     -41.100
# 88020   P00569588     -13.700
# 88025   P00569588     -41.100
# 88026   P00599983     -27.400
#
# [8549 rows x 16 columns]

# %% [markdown]
# #### 1.5 Handling Missing Values

# %%
data.isnull().sum()
# Out:
# Transaction Date              0
# Card Category                 0
# Card Type                     0
# Channel                       0
# Transaction Type              0
# Transaction Type Group        0
# Entry Mode                    0
# Transaction Status            0
# Outlet ID                     0
#  Merchant Acronym           570
# Merchant Desc               580
# Merchant Country              0
# Merchant Activity         38517
# Merchant Activity sub         0
# Client Code                   0
# Amount USD                    0
# dtype: int64
